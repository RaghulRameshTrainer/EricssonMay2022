# %%
import pandas as pd
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',100)

# %%
df=pd.read_csv(r'C:\Users\RaghulRamesh\Ericsson_16May\company.csv')

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
df.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df
# Out:
#                        Company   Age  Salary       Place Country  Gender
# 0                          TCS  20.0     NaN     Chennai   India       0
# 1                      Infosys  30.0     NaN      Mumbai   India       0
# 2                          TCS  35.0  2300.0    Calcutta   India       0
# 3                      Infosys  40.0  3000.0       Delhi   India       0
# 4                          TCS  23.0  4000.0      Mumbai   India       0
# 5                      Infosys   NaN  5000.0    Calcutta   India       0
# 6                          TCS   NaN  6000.0     Chennai   India       1
# 7                      Infosys  23.0  7000.0      Mumbai   India       1
# 8                          TCS  34.0  8000.0    Calcutta   India       1
# 9                          CTS  45.0  9000.0       Delhi   India       0
# 10                         CTS  23.0     NaN      Mumbai   India       0
# 11                         CTS  34.0  1089.0    Calcutta   India       0
# ...

# %%
df.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS','Congnizant':'CTS','Infosys Pvt Lmt':'Infosys'},inplace=True)

# %%
df['Company']
# Out:
# 0          TCS
# 1      Infosys
# 2          TCS
# 3      Infosys
# 4          TCS
# 5      Infosys
# 6          TCS
# 7      Infosys
# 8          TCS
# 9          CTS
# 10         CTS
# 11         CTS
# 12         CTS
# 13         CTS
# 14     Infosys
# 15         TCS
# 16     Infosys
# 17         TCS
# 18         TCS
# 19     Infosys
# 20         TCS
# 21     Infosys
# 22         TCS
# 23     Infosys
# 24         TCS
# 25     Infosys
# 26         TCS
# 27         CTS
# 28         CTS
# 29         CTS
# 30         CTS
# 31         CTS
# 32     Infosys
# 33         TCS
# 34     Infosys
# 35         TCS
# 36         TCS
# 37         NaN
# 38         TCS
# 39     Infosys
# 40         TCS
# 41     Infosys
# 42         TCS
# 43     Infosys
# 44         TCS
# 45         CTS
# 46         CTS
# 47         CTS
# 48         CTS
# 49         CTS
# 50     Infosys
# 51         NaN
# 52     Infosys
# 53         TCS
# 54         TCS
# 55     Infosys
# 56         TCS
# 57     Infosys
# ...

# %%
df['Company'].value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan], dtype=object)

# %%
df['Company'].fillna('Ericcson')
# Out:
# 0           TCS
# 1       Infosys
# 2           TCS
# 3       Infosys
# 4           TCS
# 5       Infosys
# 6           TCS
# 7       Infosys
# 8           TCS
# 9           CTS
# 10          CTS
# 11          CTS
# 12          CTS
# 13          CTS
# 14      Infosys
# 15          TCS
# 16      Infosys
# 17          TCS
# 18          TCS
# 19      Infosys
# 20          TCS
# 21      Infosys
# 22          TCS
# 23      Infosys
# 24          TCS
# 25      Infosys
# 26          TCS
# 27          CTS
# 28          CTS
# 29          CTS
# 30          CTS
# 31          CTS
# 32      Infosys
# 33          TCS
# 34      Infosys
# 35          TCS
# 36          TCS
# 37     Ericcson
# 38          TCS
# 39      Infosys
# 40          TCS
# 41      Infosys
# 42          TCS
# 43      Infosys
# 44          TCS
# 45          CTS
# 46          CTS
# 47          CTS
# 48          CTS
# 49          CTS
# 50      Infosys
# 51     Ericcson
# 52      Infosys
# 53          TCS
# 54          TCS
# ...

# %%
df['Company'].mode()
# Out:
# 0    TCS
# Name: Company, dtype: object

# %%
df['Company'].fillna(df['Company'].mode()[0],inplace=True)

# %%
df['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS'], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# TCS        63
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df['Company']
# Out:
# 0          TCS
# 1      Infosys
# 2          TCS
# 3      Infosys
# 4          TCS
# 5      Infosys
# 6          TCS
# 7      Infosys
# 8          TCS
# 9          CTS
# 10         CTS
# 11         CTS
# 12         CTS
# 13         CTS
# 14     Infosys
# 15         TCS
# 16     Infosys
# 17         TCS
# 18         TCS
# 19     Infosys
# 20         TCS
# 21     Infosys
# 22         TCS
# 23     Infosys
# 24         TCS
# 25     Infosys
# 26         TCS
# 27         CTS
# 28         CTS
# 29         CTS
# 30         CTS
# 31         CTS
# 32     Infosys
# 33         TCS
# 34     Infosys
# 35         TCS
# 36         TCS
# 37         TCS
# 38         TCS
# 39     Infosys
# 40         TCS
# 41     Infosys
# 42         TCS
# 43     Infosys
# 44         TCS
# 45         CTS
# 46         CTS
# 47         CTS
# 48         CTS
# 49         CTS
# 50     Infosys
# 51         TCS
# 52     Infosys
# 53         TCS
# 54         TCS
# 55     Infosys
# 56         TCS
# 57     Infosys
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].mean()
# Out:
# 30.484615384615385

# %%
df['Age'].isna().sum()
# Out:
# 18

# %%
df['Age']
# Out:
# 0      20.0
# 1      30.0
# 2      35.0
# 3      40.0
# 4      23.0
# 5       NaN
# 6       NaN
# 7      23.0
# 8      34.0
# 9      45.0
# 10     23.0
# 11     34.0
# 12     45.0
# 13     18.0
# 14     40.0
# 15     23.0
# 16     23.0
# 17     34.0
# 18     22.0
# 19     32.0
# 20     37.0
# 21     50.0
# 22     21.0
# 23      NaN
# 24      NaN
# 25     23.0
# 26     34.0
# 27     45.0
# 28     23.0
# 29     35.0
# 30     46.0
# 31     20.0
# 32     45.0
# 33     36.0
# 34     26.0
# 35     35.0
# 36     32.0
# 37     35.0
# 38     34.0
# 39     41.0
# 40     24.0
# 41      NaN
# 42      NaN
# 43     25.0
# 44     35.0
# 45     46.0
# 46     24.0
# 47     32.0
# 48     43.0
# 49     19.0
# 50     41.0
# 51     24.0
# 52     21.0
# 53     35.0
# 54     21.0
# 55     32.0
# 56     38.0
# 57     51.0
# 58     23.0
# 59      NaN
# 60      NaN
# 61     25.0
# 62     36.0
# 63     41.0
# 64     25.0
# 65     31.0
# 66     41.0
# 67     21.0
# 68     43.0
# 69     32.0
# 70     21.0
# ...

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df[df['Age']<21]
# Out:
#      Company   Age  Salary       Place Country  Gender
# 0        TCS  20.0     NaN     Chennai   India       0
# 13       CTS  18.0  1234.0      Mumbai   India       0
# 31       CTS  20.0  2934.0      Mumbai   India       0
# 49       CTS  19.0  1234.0      Cochin   India       0
# 85       CTS  17.0  1234.0    Calcutta   India       0
# 88   Infosys   0.0  3030.0    Calcutta   India       0
# 92       TCS   0.0  3045.0       Delhi   India       0
# 101      CTS   0.0  2034.0  Podicherry   India       0
# 107      TCS   0.0  9024.0     Chennai   India       1
# 111  Infosys   0.0  3234.0      Mumbai   India       0
# 121      CTS   0.0  1234.0    Calcutta   India       0
# 126      TCS  20.0  5009.0         NaN   India       1

# %%
df['Age'].replace({0:21},inplace=True)

# %%
df[df['Age']<21]
# Out:
#     Company   Age  Salary     Place Country  Gender
# 0       TCS  20.0     NaN   Chennai   India       0
# 13      CTS  18.0  1234.0    Mumbai   India       0
# 31      CTS  20.0  2934.0    Mumbai   India       0
# 49      CTS  19.0  1234.0    Cochin   India       0
# 85      CTS  17.0  1234.0  Calcutta   India       0
# 126     TCS  20.0  5009.0       NaN   India       1

# %%
df['Salary'].describe()
# Out:
# count     124.000000
# mean     5312.467742
# std      2573.764683
# min      1089.000000
# 25%      3030.000000
# 50%      5000.000000
# 75%      8000.000000
# max      9876.000000
# Name: Salary, dtype: float64

# %%
df['Salary'].isna().sum()
# Out:
# 24

# %%
df['Salary'].fillna(df['Salary'].mean(),inplace=True)

# %%
df['Salary'].isna().sum()
# Out:
# 0

# %%
df['Place'].isna().sum()
# Out:
# 14

# %%
df['Place'].value_counts()
# Out:
# Mumbai        37
# Calcutta      33
# Chennai       14
# Delhi         14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: Place, dtype: int64

# %%
df['Place'].fillna('Delhi',inplace=True)

# %%
df['Place'].isna().sum()
# Out:
# 0

# %%
df['Place'].value_counts()
# Out:
# Mumbai        37
# Calcutta      33
# Delhi         28
# Chennai       14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: Place, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# India    148
# Name: Country, dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Gender']=df['Gender'].replace({0:'M',1:'F'})

# %%
df.head(15)
# Out:
#     Company        Age       Salary     Place Country Gender
# 0       TCS  20.000000  5312.467742   Chennai   India      M
# 1   Infosys  30.000000  5312.467742    Mumbai   India      M
# 2       TCS  35.000000  2300.000000  Calcutta   India      M
# 3   Infosys  40.000000  3000.000000     Delhi   India      M
# 4       TCS  23.000000  4000.000000    Mumbai   India      M
# 5   Infosys  30.484615  5000.000000  Calcutta   India      M
# 6       TCS  30.484615  6000.000000   Chennai   India      F
# 7   Infosys  23.000000  7000.000000    Mumbai   India      F
# 8       TCS  34.000000  8000.000000  Calcutta   India      F
# 9       CTS  45.000000  9000.000000     Delhi   India      M
# 10      CTS  23.000000  5312.467742    Mumbai   India      M
# 11      CTS  34.000000  1089.000000  Calcutta   India      M
# 12      CTS  45.000000  5312.467742   Chennai   India      M
# 13      CTS  18.000000  1234.000000    Mumbai   India      M
# ...

# %%
df
# Out:
#      Company        Age       Salary       Place Country Gender
# 0        TCS  20.000000  5312.467742     Chennai   India      M
# 1    Infosys  30.000000  5312.467742      Mumbai   India      M
# 2        TCS  35.000000  2300.000000    Calcutta   India      M
# 3    Infosys  40.000000  3000.000000       Delhi   India      M
# 4        TCS  23.000000  4000.000000      Mumbai   India      M
# 5    Infosys  30.484615  5000.000000    Calcutta   India      M
# 6        TCS  30.484615  6000.000000     Chennai   India      F
# 7    Infosys  23.000000  7000.000000      Mumbai   India      F
# 8        TCS  34.000000  8000.000000    Calcutta   India      F
# 9        CTS  45.000000  9000.000000       Delhi   India      M
# 10       CTS  23.000000  5312.467742      Mumbai   India      M
# 11       CTS  34.000000  1089.000000    Calcutta   India      M
# 12       CTS  45.000000  5312.467742     Chennai   India      M
# 13       CTS  18.000000  1234.000000      Mumbai   India      M
# ...

# %%
df=df.rename(columns={'Place':'City'})

# %%
df.head()
# Out:
#    Company   Age       Salary      City Country Gender
# 0      TCS  20.0  5312.467742   Chennai   India      M
# 1  Infosys  30.0  5312.467742    Mumbai   India      M
# 2      TCS  35.0  2300.000000  Calcutta   India      M
# 3  Infosys  40.0  3000.000000     Delhi   India      M
# 4      TCS  23.0  4000.000000    Mumbai   India      M

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df[df.duplicated()]
# Out:
#      Company        Age       Salary      City Country Gender
# 84       CTS  43.000000  5312.467742    Mumbai   India      M
# 88   Infosys  21.000000  3030.000000  Calcutta   India      M
# 130      TCS  21.000000  4824.000000    Mumbai   India      M
# 131  Infosys  30.484615  5835.000000    Mumbai   India      M
# 144  Infosys  22.000000  8787.000000  Calcutta   India      F

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values(by=['Salary'],ascending=False)
# Out:
#      Company        Age       Salary        City Country Gender
# 117      CTS  44.000000  9876.000000       Delhi   India      F
# 28       CTS  23.000000  9876.000000      Mumbai   India      F
# 99       CTS  44.000000  9284.000000  Podicherry   India      F
# 63       CTS  41.000000  9284.000000       Delhi   India      F
# 27       CTS  45.000000  9284.000000       Delhi   India      F
# 135      CTS  40.000000  9284.000000    Calcutta   India      F
# 71       TCS  34.000000  9024.000000      Mumbai   India      F
# 35       TCS  35.000000  9024.000000       Delhi   India      F
# 107      TCS  21.000000  9024.000000     Chennai   India      F
# 143      TCS  33.000000  9024.000000    Calcutta   India      F
# 9        CTS  45.000000  9000.000000       Delhi   India      M
# 45       CTS  46.000000  9000.000000   Hyderabad   India      F
# 81       CTS  43.000000  9000.000000        Pune   India      F
# 133      TCS  22.000000  8943.000000     Chennai   India      M
# ...

# %%
df.sort_values(by=['Salary','Age'],ascending=False)
# Out:
#      Company        Age       Salary        City Country Gender
# 117      CTS  44.000000  9876.000000       Delhi   India      F
# 28       CTS  23.000000  9876.000000      Mumbai   India      F
# 27       CTS  45.000000  9284.000000       Delhi   India      F
# 99       CTS  44.000000  9284.000000  Podicherry   India      F
# 63       CTS  41.000000  9284.000000       Delhi   India      F
# 135      CTS  40.000000  9284.000000    Calcutta   India      F
# 35       TCS  35.000000  9024.000000       Delhi   India      F
# 71       TCS  34.000000  9024.000000      Mumbai   India      F
# 143      TCS  33.000000  9024.000000    Calcutta   India      F
# 107      TCS  21.000000  9024.000000     Chennai   India      F
# 45       CTS  46.000000  9000.000000   Hyderabad   India      F
# 9        CTS  45.000000  9000.000000       Delhi   India      M
# 81       CTS  43.000000  9000.000000        Pune   India      F
# 61       TCS  25.000000  8943.000000       Delhi   India      F
# ...

# %%
df.groupby('Company').max()
# Out:
#           Age  Salary        City Country Gender
# Company
# CTS      46.0  9876.0        Pune   India      M
# Infosys  54.0  8943.0  Podicherry   India      M
# TCS      38.0  9024.0       Noida   India      M

# %%
df.groupby(['Company','City','Gender'])['Salary'].agg(['min','max','mean'])
# Out:
#                                    min          max         mean
# Company City       Gender
# CTS     Calcutta   F       9284.000000  9284.000000  9284.000000
#                    M       1089.000000  5312.467742  2852.655914
#         Chennai    M       1089.000000  7654.000000  4685.155914
#         Cochin     M       1234.000000  5312.467742  2903.366935
#         Delhi      F       9284.000000  9876.000000  9481.333333
#                    M       5312.467742  9000.000000  7156.233871
#         Hyderabad  F       9000.000000  9000.000000  9000.000000
#                    M       2034.000000  5312.467742  3673.233871
#         Mumbai     F       9876.000000  9876.000000  9876.000000
#                    M       1089.000000  5312.467742  3270.300403
#         Noida      M       1089.000000  2934.000000  2011.500000
#         Podicherry F       9284.000000  9284.000000  9284.000000
#                    M       2034.000000  2034.000000  2034.000000
# ...

# %%
df.head()
# Out:
#    Company   Age       Salary      City Country Gender
# 0      TCS  20.0  5312.467742   Chennai   India      M
# 1  Infosys  30.0  5312.467742    Mumbai   India      M
# 2      TCS  35.0  2300.000000  Calcutta   India      M
# 3  Infosys  40.0  3000.000000     Delhi   India      M
# 4      TCS  23.0  4000.000000    Mumbai   India      M

# %%
df.iloc[0:10,0:4]
# Out:
#    Company        Age       Salary      City
# 0      TCS  20.000000  5312.467742   Chennai
# 1  Infosys  30.000000  5312.467742    Mumbai
# 2      TCS  35.000000  2300.000000  Calcutta
# 3  Infosys  40.000000  3000.000000     Delhi
# 4      TCS  23.000000  4000.000000    Mumbai
# 5  Infosys  30.484615  5000.000000  Calcutta
# 6      TCS  30.484615  6000.000000   Chennai
# 7  Infosys  23.000000  7000.000000    Mumbai
# 8      TCS  34.000000  8000.000000  Calcutta
# 9      CTS  45.000000  9000.000000     Delhi

# %%
df.iloc[100,:]
# Out:
# Company            CTS
# Age               44.0
# Salary     5312.467742
# City            Mumbai
# Country          India
# Gender               M
# Name: 102, dtype: object

# %%
df.iloc[100:105,0:3]
# Out:
#      Company   Age       Salary
# 102      CTS  44.0  5312.467742
# 103      CTS  22.0  2934.000000
# 104  Infosys  44.0  4034.000000
# 105      TCS  33.0  5034.000000
# 106  Infosys  22.0  8202.000000

# %%
df.head()
# Out:
#    Company   Age       Salary      City Country Gender
# 0      TCS  20.0  5312.467742   Chennai   India      M
# 1  Infosys  30.0  5312.467742    Mumbai   India      M
# 2      TCS  35.0  2300.000000  Calcutta   India      M
# 3  Infosys  40.0  3000.000000     Delhi   India      M
# 4      TCS  23.0  4000.000000    Mumbai   India      M

# %%
df.loc[100:105,['City','Salary']]
# Out:
#            City       Salary
# 100      Cochin  5312.467742
# 101  Podicherry  2034.000000
# 102      Mumbai  5312.467742
# 103    Calcutta  2934.000000
# 104       Delhi  4034.000000
# 105      Mumbai  5034.000000
